# %%
#!/usr/bin/python3.5  
# -*- coding: utf-8 -*-  
  
import os
import sys
import tensorflow as tf  
from tensorflow.examples.tutorials.mnist import input_data   
from PIL import Image  



# 声明图片宽高  
rows = 28  
cols = 28  
  
#创建会话  
sess = tf.Session()  
  
def mnistToimage(images, labels, save_dir, images_to_extract=8000):
    shape = sess.run(tf.shape(images))
    # 获取图片总数  
    images_count = shape[0]  
    pixels_per_image = shape[1]
    # 获取标签总数  
    shape = sess.run(tf.shape(labels))  
    labels_count = shape[0] 
    #一共有多少分类
    labels_classification_count = shape[1]
    labels = sess.run(tf.argmax(mnist.train.labels, 1))  
    
    if (images_count == labels_count):
        print ("Total %s images，%s lables" % (images_count, labels_count))  
        print ("每张图片包含 %s 个像素" % (pixels_per_image))  
        print ("数据类型：%s" % (mnist.train.images.dtype))    
    # mnist图像数据的数值范围是[0,1]，需要扩展到[0,255]，以便于人眼观看  
        if images.dtype == "float32":  
            print ("准备将数据类型从[0,1]转为binary[0,255]...")  
            for i in range(images_to_extract):  
                for n in range(pixels_per_image):  
                    if mnist.train.images[i][n] != 0:  
                        mnist.train.images[i][n] = 255  
                # 由于数据集图片数量庞大，转换可能要花不少时间，有必要打印转换进度  
                if ((i+1)%50) == 0:  
                    print ("图像浮点数值扩展进度：已转换 %s 张，共需转换 %s 张" % (i+1, images_to_extract))  

        # 创建数字图片的保存目录  
        for i in range(labels_classification_count):  
            dir = "%s/%s/" % (save_dir,i)  
            if not os.path.exists(dir):  
                print ("目录 ""%s"" 不存在！自动创建该目录..." % dir)  
                os.makedirs(dir)  

        # 通过python图片处理库，生成图片  
        indices = [0 for x in range(labels_classification_count)]  
        for i in range(images_to_extract):  
            img = Image.new("L",(cols,rows))  
            for m in range(rows):  
                for n in range(cols):  
                    img.putpixel((n,m), int(mnist.train.images[i][n+m*cols]))  
            # 根据图片所代表的数字label生成对应的保存路径  
            digit = labels[i]  
            path = "%s/%s/%s.bmp" % (save_dir, labels[i], indices[digit])  
            indices[digit] += 1  
            img.save(path)  
            # 由于数据集图片数量庞大，保存过程可能要花不少时间，有必要打印保存进度  
            if ((i+1)%50) == 0:  
                print ("图片保存进度：已保存 %s 张，共需保存 %s 张" % (i+1, images_to_extract))  
      
    else:  
        print ("图片数量和标签数量不一致！")

if __name__ == "__main__":
    # 读入mnist数据  
    mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)  
    # 当前路径下的保存目录  
    train_save_dir = "./mnist_digits_images/training_image"  
    test_save_dir = "./mnist_digits_images/test_image"  
    print("Training to Test image.........")
    mnistToimage(mnist.train.images, mnist.train.labels, train_save_dir)
    print("Save to Test image.........")
    mnistToimage(mnist.test.images, mnist.test.labels, test_save_dir)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Training to Test image.........
# Total 55000 images，55000 lables
# 每张图片包含 784 个像素
# 数据类型：float32
# 准备将数据类型从[0,1]转为binary[0,255]...
# 图像浮点数值扩展进度：已转换 50 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 100 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 150 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 200 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 250 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 300 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 350 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 400 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 450 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 500 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 550 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 600 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 650 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 700 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 750 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 800 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 850 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 900 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 950 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1000 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1050 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1100 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1150 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1200 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1250 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1300 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1350 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1400 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1450 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1500 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1550 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1600 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1650 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1700 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1750 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1800 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1850 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1900 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1950 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2000 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2050 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2100 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2150 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2200 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2250 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2300 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2350 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2400 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2450 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2500 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2550 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2600 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2650 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2700 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2750 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2800 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2850 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2900 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2950 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3000 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3050 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3100 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3150 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3200 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3250 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3300 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3350 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3400 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3450 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3500 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3550 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3600 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3650 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3700 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3750 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3800 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3850 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3900 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3950 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4000 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4050 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4100 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4150 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4200 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4250 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4300 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4350 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4400 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4450 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4500 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4550 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4600 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4650 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4700 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4750 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4800 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4850 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4900 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4950 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5000 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5050 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5100 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5150 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5200 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5250 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5300 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5350 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5400 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5450 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5500 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5550 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5600 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5650 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5700 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5750 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5800 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5850 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5900 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5950 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6000 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6050 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6100 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6150 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6200 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6250 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6300 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6350 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6400 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6450 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6500 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6550 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6600 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6650 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6700 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6750 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6800 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6850 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6900 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6950 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7000 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7050 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7100 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7150 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7200 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7250 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7300 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7350 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7400 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7450 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7500 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7550 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7600 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7650 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7700 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7750 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7800 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7850 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7900 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7950 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 8000 张，共需转换 8000 张
# 目录 ./mnist_digits_images/training_image/0/ 不存在！自动创建该目录...
# 目录 ./mnist_digits_images/training_image/1/ 不存在！自动创建该目录...
# 目录 ./mnist_digits_images/training_image/2/ 不存在！自动创建该目录...
# 目录 ./mnist_digits_images/training_image/3/ 不存在！自动创建该目录...
# 目录 ./mnist_digits_images/training_image/4/ 不存在！自动创建该目录...
# 目录 ./mnist_digits_images/training_image/5/ 不存在！自动创建该目录...
# 目录 ./mnist_digits_images/training_image/6/ 不存在！自动创建该目录...
# 目录 ./mnist_digits_images/training_image/7/ 不存在！自动创建该目录...
# 目录 ./mnist_digits_images/training_image/8/ 不存在！自动创建该目录...
# 目录 ./mnist_digits_images/training_image/9/ 不存在！自动创建该目录...
# 图片保存进度：已保存 50 张，共需保存 8000 张
# 图片保存进度：已保存 100 张，共需保存 8000 张
# 图片保存进度：已保存 150 张，共需保存 8000 张
# 图片保存进度：已保存 200 张，共需保存 8000 张
# 图片保存进度：已保存 250 张，共需保存 8000 张
# 图片保存进度：已保存 300 张，共需保存 8000 张
# 图片保存进度：已保存 350 张，共需保存 8000 张
# 图片保存进度：已保存 400 张，共需保存 8000 张
# 图片保存进度：已保存 450 张，共需保存 8000 张
# 图片保存进度：已保存 500 张，共需保存 8000 张
# 图片保存进度：已保存 550 张，共需保存 8000 张
# 图片保存进度：已保存 600 张，共需保存 8000 张
# 图片保存进度：已保存 650 张，共需保存 8000 张
# 图片保存进度：已保存 700 张，共需保存 8000 张
# 图片保存进度：已保存 750 张，共需保存 8000 张
# 图片保存进度：已保存 800 张，共需保存 8000 张
# 图片保存进度：已保存 850 张，共需保存 8000 张
# 图片保存进度：已保存 900 张，共需保存 8000 张
# 图片保存进度：已保存 950 张，共需保存 8000 张
# 图片保存进度：已保存 1000 张，共需保存 8000 张
# 图片保存进度：已保存 1050 张，共需保存 8000 张
# 图片保存进度：已保存 1100 张，共需保存 8000 张
# 图片保存进度：已保存 1150 张，共需保存 8000 张
# 图片保存进度：已保存 1200 张，共需保存 8000 张
# 图片保存进度：已保存 1250 张，共需保存 8000 张
# 图片保存进度：已保存 1300 张，共需保存 8000 张
# 图片保存进度：已保存 1350 张，共需保存 8000 张
# 图片保存进度：已保存 1400 张，共需保存 8000 张
# 图片保存进度：已保存 1450 张，共需保存 8000 张
# 图片保存进度：已保存 1500 张，共需保存 8000 张
# 图片保存进度：已保存 1550 张，共需保存 8000 张
# 图片保存进度：已保存 1600 张，共需保存 8000 张
# 图片保存进度：已保存 1650 张，共需保存 8000 张
# 图片保存进度：已保存 1700 张，共需保存 8000 张
# 图片保存进度：已保存 1750 张，共需保存 8000 张
# 图片保存进度：已保存 1800 张，共需保存 8000 张
# 图片保存进度：已保存 1850 张，共需保存 8000 张
# 图片保存进度：已保存 1900 张，共需保存 8000 张
# 图片保存进度：已保存 1950 张，共需保存 8000 张
# 图片保存进度：已保存 2000 张，共需保存 8000 张
# 图片保存进度：已保存 2050 张，共需保存 8000 张
# 图片保存进度：已保存 2100 张，共需保存 8000 张
# 图片保存进度：已保存 2150 张，共需保存 8000 张
# 图片保存进度：已保存 2200 张，共需保存 8000 张
# 图片保存进度：已保存 2250 张，共需保存 8000 张
# 图片保存进度：已保存 2300 张，共需保存 8000 张
# 图片保存进度：已保存 2350 张，共需保存 8000 张
# 图片保存进度：已保存 2400 张，共需保存 8000 张
# 图片保存进度：已保存 2450 张，共需保存 8000 张
# 图片保存进度：已保存 2500 张，共需保存 8000 张
# 图片保存进度：已保存 2550 张，共需保存 8000 张
# 图片保存进度：已保存 2600 张，共需保存 8000 张
# 图片保存进度：已保存 2650 张，共需保存 8000 张
# 图片保存进度：已保存 2700 张，共需保存 8000 张
# 图片保存进度：已保存 2750 张，共需保存 8000 张
# 图片保存进度：已保存 2800 张，共需保存 8000 张
# 图片保存进度：已保存 2850 张，共需保存 8000 张
# 图片保存进度：已保存 2900 张，共需保存 8000 张
# 图片保存进度：已保存 2950 张，共需保存 8000 张
# 图片保存进度：已保存 3000 张，共需保存 8000 张
# 图片保存进度：已保存 3050 张，共需保存 8000 张
# 图片保存进度：已保存 3100 张，共需保存 8000 张
# 图片保存进度：已保存 3150 张，共需保存 8000 张
# 图片保存进度：已保存 3200 张，共需保存 8000 张
# 图片保存进度：已保存 3250 张，共需保存 8000 张
# 图片保存进度：已保存 3300 张，共需保存 8000 张
# 图片保存进度：已保存 3350 张，共需保存 8000 张
# 图片保存进度：已保存 3400 张，共需保存 8000 张
# 图片保存进度：已保存 3450 张，共需保存 8000 张
# 图片保存进度：已保存 3500 张，共需保存 8000 张
# 图片保存进度：已保存 3550 张，共需保存 8000 张
# 图片保存进度：已保存 3600 张，共需保存 8000 张
# 图片保存进度：已保存 3650 张，共需保存 8000 张
# 图片保存进度：已保存 3700 张，共需保存 8000 张
# 图片保存进度：已保存 3750 张，共需保存 8000 张
# 图片保存进度：已保存 3800 张，共需保存 8000 张
# 图片保存进度：已保存 3850 张，共需保存 8000 张
# 图片保存进度：已保存 3900 张，共需保存 8000 张
# 图片保存进度：已保存 3950 张，共需保存 8000 张
# 图片保存进度：已保存 4000 张，共需保存 8000 张
# 图片保存进度：已保存 4050 张，共需保存 8000 张
# 图片保存进度：已保存 4100 张，共需保存 8000 张
# 图片保存进度：已保存 4150 张，共需保存 8000 张
# 图片保存进度：已保存 4200 张，共需保存 8000 张
# 图片保存进度：已保存 4250 张，共需保存 8000 张
# 图片保存进度：已保存 4300 张，共需保存 8000 张
# 图片保存进度：已保存 4350 张，共需保存 8000 张
# 图片保存进度：已保存 4400 张，共需保存 8000 张
# 图片保存进度：已保存 4450 张，共需保存 8000 张
# 图片保存进度：已保存 4500 张，共需保存 8000 张
# 图片保存进度：已保存 4550 张，共需保存 8000 张
# 图片保存进度：已保存 4600 张，共需保存 8000 张
# 图片保存进度：已保存 4650 张，共需保存 8000 张
# 图片保存进度：已保存 4700 张，共需保存 8000 张
# 图片保存进度：已保存 4750 张，共需保存 8000 张
# 图片保存进度：已保存 4800 张，共需保存 8000 张
# 图片保存进度：已保存 4850 张，共需保存 8000 张
# 图片保存进度：已保存 4900 张，共需保存 8000 张
# 图片保存进度：已保存 4950 张，共需保存 8000 张
# 图片保存进度：已保存 5000 张，共需保存 8000 张
# 图片保存进度：已保存 5050 张，共需保存 8000 张
# 图片保存进度：已保存 5100 张，共需保存 8000 张
# 图片保存进度：已保存 5150 张，共需保存 8000 张
# 图片保存进度：已保存 5200 张，共需保存 8000 张
# 图片保存进度：已保存 5250 张，共需保存 8000 张
# 图片保存进度：已保存 5300 张，共需保存 8000 张
# 图片保存进度：已保存 5350 张，共需保存 8000 张
# 图片保存进度：已保存 5400 张，共需保存 8000 张
# 图片保存进度：已保存 5450 张，共需保存 8000 张
# 图片保存进度：已保存 5500 张，共需保存 8000 张
# 图片保存进度：已保存 5550 张，共需保存 8000 张
# 图片保存进度：已保存 5600 张，共需保存 8000 张
# 图片保存进度：已保存 5650 张，共需保存 8000 张
# 图片保存进度：已保存 5700 张，共需保存 8000 张
# 图片保存进度：已保存 5750 张，共需保存 8000 张
# 图片保存进度：已保存 5800 张，共需保存 8000 张
# 图片保存进度：已保存 5850 张，共需保存 8000 张
# 图片保存进度：已保存 5900 张，共需保存 8000 张
# 图片保存进度：已保存 5950 张，共需保存 8000 张
# 图片保存进度：已保存 6000 张，共需保存 8000 张
# 图片保存进度：已保存 6050 张，共需保存 8000 张
# 图片保存进度：已保存 6100 张，共需保存 8000 张
# 图片保存进度：已保存 6150 张，共需保存 8000 张
# 图片保存进度：已保存 6200 张，共需保存 8000 张
# 图片保存进度：已保存 6250 张，共需保存 8000 张
# 图片保存进度：已保存 6300 张，共需保存 8000 张
# 图片保存进度：已保存 6350 张，共需保存 8000 张
# 图片保存进度：已保存 6400 张，共需保存 8000 张
# 图片保存进度：已保存 6450 张，共需保存 8000 张
# 图片保存进度：已保存 6500 张，共需保存 8000 张
# 图片保存进度：已保存 6550 张，共需保存 8000 张
# 图片保存进度：已保存 6600 张，共需保存 8000 张
# 图片保存进度：已保存 6650 张，共需保存 8000 张
# 图片保存进度：已保存 6700 张，共需保存 8000 张
# 图片保存进度：已保存 6750 张，共需保存 8000 张
# 图片保存进度：已保存 6800 张，共需保存 8000 张
# 图片保存进度：已保存 6850 张，共需保存 8000 张
# 图片保存进度：已保存 6900 张，共需保存 8000 张
# 图片保存进度：已保存 6950 张，共需保存 8000 张
# 图片保存进度：已保存 7000 张，共需保存 8000 张
# 图片保存进度：已保存 7050 张，共需保存 8000 张
# 图片保存进度：已保存 7100 张，共需保存 8000 张
# 图片保存进度：已保存 7150 张，共需保存 8000 张
# 图片保存进度：已保存 7200 张，共需保存 8000 张
# 图片保存进度：已保存 7250 张，共需保存 8000 张
# 图片保存进度：已保存 7300 张，共需保存 8000 张
# 图片保存进度：已保存 7350 张，共需保存 8000 张
# 图片保存进度：已保存 7400 张，共需保存 8000 张
# 图片保存进度：已保存 7450 张，共需保存 8000 张
# 图片保存进度：已保存 7500 张，共需保存 8000 张
# 图片保存进度：已保存 7550 张，共需保存 8000 张
# 图片保存进度：已保存 7600 张，共需保存 8000 张
# 图片保存进度：已保存 7650 张，共需保存 8000 张
# 图片保存进度：已保存 7700 张，共需保存 8000 张
# 图片保存进度：已保存 7750 张，共需保存 8000 张
# 图片保存进度：已保存 7800 张，共需保存 8000 张
# 图片保存进度：已保存 7850 张，共需保存 8000 张
# 图片保存进度：已保存 7900 张，共需保存 8000 张
# 图片保存进度：已保存 7950 张，共需保存 8000 张
# 图片保存进度：已保存 8000 张，共需保存 8000 张
# Save to Test image.........
# Total 10000 images，10000 lables
# 每张图片包含 784 个像素
# 数据类型：float32
# 准备将数据类型从[0,1]转为binary[0,255]...
# 图像浮点数值扩展进度：已转换 50 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 100 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 150 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 200 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 250 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 300 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 350 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 400 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 450 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 500 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 550 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 600 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 650 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 700 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 750 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 800 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 850 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 900 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 950 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1000 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1050 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1100 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1150 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1200 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1250 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1300 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1350 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1400 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1450 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1500 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1550 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1600 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1650 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1700 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1750 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1800 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1850 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1900 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 1950 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2000 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2050 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2100 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2150 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2200 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2250 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2300 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2350 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2400 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2450 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2500 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2550 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2600 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2650 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2700 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2750 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2800 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2850 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2900 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 2950 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3000 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3050 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3100 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3150 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3200 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3250 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3300 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3350 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3400 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3450 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3500 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3550 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3600 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3650 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3700 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3750 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3800 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3850 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3900 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 3950 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4000 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4050 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4100 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4150 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4200 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4250 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4300 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4350 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4400 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4450 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4500 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4550 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4600 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4650 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4700 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4750 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4800 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4850 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4900 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 4950 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5000 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5050 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5100 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5150 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5200 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5250 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5300 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5350 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5400 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5450 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5500 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5550 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5600 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5650 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5700 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5750 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5800 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5850 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5900 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 5950 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6000 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6050 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6100 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6150 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6200 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6250 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6300 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6350 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6400 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6450 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6500 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6550 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6600 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6650 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6700 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6750 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6800 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6850 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6900 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 6950 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7000 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7050 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7100 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7150 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7200 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7250 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7300 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7350 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7400 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7450 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7500 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7550 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7600 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7650 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7700 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7750 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7800 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7850 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7900 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 7950 张，共需转换 8000 张
# 图像浮点数值扩展进度：已转换 8000 张，共需转换 8000 张
# 目录 ./mnist_digits_images/test_image/0/ 不存在！自动创建该目录...
# 目录 ./mnist_digits_images/test_image/1/ 不存在！自动创建该目录...
# 目录 ./mnist_digits_images/test_image/2/ 不存在！自动创建该目录...
# 目录 ./mnist_digits_images/test_image/3/ 不存在！自动创建该目录...
# 目录 ./mnist_digits_images/test_image/4/ 不存在！自动创建该目录...
# 目录 ./mnist_digits_images/test_image/5/ 不存在！自动创建该目录...
# 目录 ./mnist_digits_images/test_image/6/ 不存在！自动创建该目录...
# 目录 ./mnist_digits_images/test_image/7/ 不存在！自动创建该目录...
# 目录 ./mnist_digits_images/test_image/8/ 不存在！自动创建该目录...
# 目录 ./mnist_digits_images/test_image/9/ 不存在！自动创建该目录...
# 图片保存进度：已保存 50 张，共需保存 8000 张
# 图片保存进度：已保存 100 张，共需保存 8000 张
# 图片保存进度：已保存 150 张，共需保存 8000 张
# 图片保存进度：已保存 200 张，共需保存 8000 张
# 图片保存进度：已保存 250 张，共需保存 8000 张
# 图片保存进度：已保存 300 张，共需保存 8000 张
# 图片保存进度：已保存 350 张，共需保存 8000 张
# 图片保存进度：已保存 400 张，共需保存 8000 张
# 图片保存进度：已保存 450 张，共需保存 8000 张
# 图片保存进度：已保存 500 张，共需保存 8000 张
# 图片保存进度：已保存 550 张，共需保存 8000 张
# 图片保存进度：已保存 600 张，共需保存 8000 张
# 图片保存进度：已保存 650 张，共需保存 8000 张
# 图片保存进度：已保存 700 张，共需保存 8000 张
# 图片保存进度：已保存 750 张，共需保存 8000 张
# 图片保存进度：已保存 800 张，共需保存 8000 张
# 图片保存进度：已保存 850 张，共需保存 8000 张
# 图片保存进度：已保存 900 张，共需保存 8000 张
# 图片保存进度：已保存 950 张，共需保存 8000 张
# 图片保存进度：已保存 1000 张，共需保存 8000 张
# 图片保存进度：已保存 1050 张，共需保存 8000 张
# 图片保存进度：已保存 1100 张，共需保存 8000 张
# 图片保存进度：已保存 1150 张，共需保存 8000 张
# 图片保存进度：已保存 1200 张，共需保存 8000 张
# 图片保存进度：已保存 1250 张，共需保存 8000 张
# 图片保存进度：已保存 1300 张，共需保存 8000 张
# 图片保存进度：已保存 1350 张，共需保存 8000 张
# 图片保存进度：已保存 1400 张，共需保存 8000 张
# 图片保存进度：已保存 1450 张，共需保存 8000 张
# 图片保存进度：已保存 1500 张，共需保存 8000 张
# 图片保存进度：已保存 1550 张，共需保存 8000 张
# 图片保存进度：已保存 1600 张，共需保存 8000 张
# 图片保存进度：已保存 1650 张，共需保存 8000 张
# 图片保存进度：已保存 1700 张，共需保存 8000 张
# 图片保存进度：已保存 1750 张，共需保存 8000 张
# 图片保存进度：已保存 1800 张，共需保存 8000 张
# 图片保存进度：已保存 1850 张，共需保存 8000 张
# 图片保存进度：已保存 1900 张，共需保存 8000 张
# 图片保存进度：已保存 1950 张，共需保存 8000 张
# 图片保存进度：已保存 2000 张，共需保存 8000 张
# 图片保存进度：已保存 2050 张，共需保存 8000 张
# 图片保存进度：已保存 2100 张，共需保存 8000 张
# 图片保存进度：已保存 2150 张，共需保存 8000 张
# 图片保存进度：已保存 2200 张，共需保存 8000 张
# 图片保存进度：已保存 2250 张，共需保存 8000 张
# 图片保存进度：已保存 2300 张，共需保存 8000 张
# 图片保存进度：已保存 2350 张，共需保存 8000 张
# 图片保存进度：已保存 2400 张，共需保存 8000 张
# 图片保存进度：已保存 2450 张，共需保存 8000 张
# 图片保存进度：已保存 2500 张，共需保存 8000 张
# 图片保存进度：已保存 2550 张，共需保存 8000 张
# 图片保存进度：已保存 2600 张，共需保存 8000 张
# 图片保存进度：已保存 2650 张，共需保存 8000 张
# 图片保存进度：已保存 2700 张，共需保存 8000 张
# 图片保存进度：已保存 2750 张，共需保存 8000 张
# 图片保存进度：已保存 2800 张，共需保存 8000 张
# 图片保存进度：已保存 2850 张，共需保存 8000 张
# 图片保存进度：已保存 2900 张，共需保存 8000 张
# 图片保存进度：已保存 2950 张，共需保存 8000 张
# 图片保存进度：已保存 3000 张，共需保存 8000 张
# 图片保存进度：已保存 3050 张，共需保存 8000 张
# 图片保存进度：已保存 3100 张，共需保存 8000 张
# 图片保存进度：已保存 3150 张，共需保存 8000 张
# 图片保存进度：已保存 3200 张，共需保存 8000 张
# 图片保存进度：已保存 3250 张，共需保存 8000 张
# 图片保存进度：已保存 3300 张，共需保存 8000 张
# 图片保存进度：已保存 3350 张，共需保存 8000 张
# 图片保存进度：已保存 3400 张，共需保存 8000 张
# 图片保存进度：已保存 3450 张，共需保存 8000 张
# 图片保存进度：已保存 3500 张，共需保存 8000 张
# 图片保存进度：已保存 3550 张，共需保存 8000 张
# 图片保存进度：已保存 3600 张，共需保存 8000 张
# 图片保存进度：已保存 3650 张，共需保存 8000 张
# 图片保存进度：已保存 3700 张，共需保存 8000 张
# 图片保存进度：已保存 3750 张，共需保存 8000 张
# 图片保存进度：已保存 3800 张，共需保存 8000 张
# 图片保存进度：已保存 3850 张，共需保存 8000 张
# 图片保存进度：已保存 3900 张，共需保存 8000 张
# 图片保存进度：已保存 3950 张，共需保存 8000 张
# 图片保存进度：已保存 4000 张，共需保存 8000 张
# 图片保存进度：已保存 4050 张，共需保存 8000 张
# 图片保存进度：已保存 4100 张，共需保存 8000 张
# 图片保存进度：已保存 4150 张，共需保存 8000 张
# 图片保存进度：已保存 4200 张，共需保存 8000 张
# 图片保存进度：已保存 4250 张，共需保存 8000 张
# 图片保存进度：已保存 4300 张，共需保存 8000 张
# 图片保存进度：已保存 4350 张，共需保存 8000 张
# 图片保存进度：已保存 4400 张，共需保存 8000 张
# 图片保存进度：已保存 4450 张，共需保存 8000 张
# 图片保存进度：已保存 4500 张，共需保存 8000 张
# 图片保存进度：已保存 4550 张，共需保存 8000 张
# 图片保存进度：已保存 4600 张，共需保存 8000 张
# 图片保存进度：已保存 4650 张，共需保存 8000 张
# 图片保存进度：已保存 4700 张，共需保存 8000 张
# 图片保存进度：已保存 4750 张，共需保存 8000 张
# 图片保存进度：已保存 4800 张，共需保存 8000 张
# 图片保存进度：已保存 4850 张，共需保存 8000 张
# 图片保存进度：已保存 4900 张，共需保存 8000 张
# 图片保存进度：已保存 4950 张，共需保存 8000 张
# 图片保存进度：已保存 5000 张，共需保存 8000 张
# 图片保存进度：已保存 5050 张，共需保存 8000 张
# 图片保存进度：已保存 5100 张，共需保存 8000 张
# 图片保存进度：已保存 5150 张，共需保存 8000 张
# 图片保存进度：已保存 5200 张，共需保存 8000 张
# 图片保存进度：已保存 5250 张，共需保存 8000 张
# 图片保存进度：已保存 5300 张，共需保存 8000 张
# 图片保存进度：已保存 5350 张，共需保存 8000 张
# 图片保存进度：已保存 5400 张，共需保存 8000 张
# 图片保存进度：已保存 5450 张，共需保存 8000 张
# 图片保存进度：已保存 5500 张，共需保存 8000 张
# 图片保存进度：已保存 5550 张，共需保存 8000 张
# 图片保存进度：已保存 5600 张，共需保存 8000 张
# 图片保存进度：已保存 5650 张，共需保存 8000 张
# 图片保存进度：已保存 5700 张，共需保存 8000 张
# 图片保存进度：已保存 5750 张，共需保存 8000 张
# 图片保存进度：已保存 5800 张，共需保存 8000 张
# 图片保存进度：已保存 5850 张，共需保存 8000 张
# 图片保存进度：已保存 5900 张，共需保存 8000 张
# 图片保存进度：已保存 5950 张，共需保存 8000 张
# 图片保存进度：已保存 6000 张，共需保存 8000 张
# 图片保存进度：已保存 6050 张，共需保存 8000 张
# 图片保存进度：已保存 6100 张，共需保存 8000 张
# 图片保存进度：已保存 6150 张，共需保存 8000 张
# 图片保存进度：已保存 6200 张，共需保存 8000 张
# 图片保存进度：已保存 6250 张，共需保存 8000 张
# 图片保存进度：已保存 6300 张，共需保存 8000 张
# 图片保存进度：已保存 6350 张，共需保存 8000 张
# 图片保存进度：已保存 6400 张，共需保存 8000 张
# 图片保存进度：已保存 6450 张，共需保存 8000 张
# 图片保存进度：已保存 6500 张，共需保存 8000 张
# 图片保存进度：已保存 6550 张，共需保存 8000 张
# 图片保存进度：已保存 6600 张，共需保存 8000 张
# 图片保存进度：已保存 6650 张，共需保存 8000 张
# 图片保存进度：已保存 6700 张，共需保存 8000 张
# 图片保存进度：已保存 6750 张，共需保存 8000 张
# 图片保存进度：已保存 6800 张，共需保存 8000 张
# 图片保存进度：已保存 6850 张，共需保存 8000 张
# 图片保存进度：已保存 6900 张，共需保存 8000 张
# 图片保存进度：已保存 6950 张，共需保存 8000 张
# 图片保存进度：已保存 7000 张，共需保存 8000 张
# 图片保存进度：已保存 7050 张，共需保存 8000 张
# 图片保存进度：已保存 7100 张，共需保存 8000 张
# 图片保存进度：已保存 7150 张，共需保存 8000 张
# 图片保存进度：已保存 7200 张，共需保存 8000 张
# 图片保存进度：已保存 7250 张，共需保存 8000 张
# 图片保存进度：已保存 7300 张，共需保存 8000 张
# 图片保存进度：已保存 7350 张，共需保存 8000 张
# 图片保存进度：已保存 7400 张，共需保存 8000 张
# 图片保存进度：已保存 7450 张，共需保存 8000 张
# 图片保存进度：已保存 7500 张，共需保存 8000 张
# 图片保存进度：已保存 7550 张，共需保存 8000 张
# 图片保存进度：已保存 7600 张，共需保存 8000 张
# 图片保存进度：已保存 7650 张，共需保存 8000 张
# 图片保存进度：已保存 7700 张，共需保存 8000 张
# 图片保存进度：已保存 7750 张，共需保存 8000 张
# 图片保存进度：已保存 7800 张，共需保存 8000 张
# 图片保存进度：已保存 7850 张，共需保存 8000 张
# 图片保存进度：已保存 7900 张，共需保存 8000 张
# 图片保存进度：已保存 7950 张，共需保存 8000 张
# 图片保存进度：已保存 8000 张，共需保存 8000 张
